# %% [markdown]
# Collect the dataset from the below link
# https://www.kaggle.com/arbethi/wild-animal-detection-and-alerting-system

# %% [markdown]
# Import ImageDataGenerator Library

# %%
#Import ImageDataGenerator Library
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#Define the parameters /arguments for ImageDataGenerator class
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,
        rotation_range=180,zoom_range=0.2,horizontal_flip=True)

test_datagen=ImageDataGenerator(rescale=1./255)

# %% [markdown]
# Applying ImageDataGenerator functionality to trainset and testset.

# %%
#Applying ImageDataGenerator functionality to trainset
x_train=train_datagen.flow_from_directory(
    directory= r"C:\Users\Manasa\Desktop\project\Intelligent-alert-system-for-forest-tribal-people-main\Dataset\train_set",
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical')

#Applying ImageDataGenerator functionality to test set
x_test=test_datagen.flow_from_directory(
    directory= r"C:\Users\Manasa\Desktop\project\Intelligent-alert-system-for-forest-tribal-people-main\Dataset\test_set",
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 993 images belonging to 3 classes.
# Found 353 images belonging to 3 classes.

# %% [markdown]
# Importing the model building libraries

# %%
'''Importing the model building libraries'''
#to define linear initializations import Sequential
from tensorflow.keras.models import Sequential
#To add layers import Dense
from tensorflow.keras.layers import Dense
# to create a convolution kernel import Convolution2D
from tensorflow.keras.layers import Convolution2D
# Adding Max pooling Layer
from tensorflow.keras.layers import MaxPooling2D
# Adding Flatten Layer
from tensorflow.keras.layers import Flatten

# %% [markdown]
# Initializing the model

# %%
# Initializing the model
model=Sequential()

# %% [markdown]
# Adding Convolutional Layer

# %%
# Adding CNN layers
model.add(Convolution2D(32,(3,3),input_shape=(64,64,3),
                        activation='relu'))

# %% [markdown]
# Adding Max pooling Layer

# %%
# Adding Max pooling Layer
model.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# Adding Flatten Layer

# %%
# Adding Flatten Layer
model.add(Flatten())

# %% [markdown]
# Adding Dense layers

# %%
# Adding Hidden Layers
model.add(Dense(kernel_initializer='uniform',activation='relu',units=300))

# %%
# Adding 2nd hidden layer
model.add(Dense(kernel_initializer='uniform',activation='relu',units=100))

# %%
# Adding 3rd hidden layer
model.add(Dense(kernel_initializer='uniform',activation='relu',units=60))

# %% [markdown]
# Adding output layer

# %%
# Adding output layer
model.add(Dense(kernel_initializer='uniform',activation='softmax',units=3))

# %% [markdown]
# Configure the learning process or compile the model

# %%
# Configure the learning process
model.compile(loss='categorical_crossentropy',
              optimizer='adam',metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30752)             0
# _________________________________________________________________
# dense (Dense)                (None, 300)               9225900
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 60)                6060
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 183
# =================================================================
# Total params: 9,263,139
# Trainable params: 9,263,139
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(x_train.class_indices)
# Out:
# {'Domestic': 0, 'Human': 1, 'Wild': 2}

# %% [markdown]
# Training the model

# %%
# Training the model
model.fit(x_train,steps_per_epoch=993//32,
                    epochs=15,
                    validation_data=x_test,
                    validation_steps=353//32)
# Out:
# Epoch 1/15
# 31/31 [==============================] - 8s 225ms/step - loss: 1.0986 - accuracy: 0.3881 - val_loss: 1.0668 - val_accuracy: 0.4545
# Epoch 2/15
# 31/31 [==============================] - 6s 202ms/step - loss: 1.0852 - accuracy: 0.3777 - val_loss: 1.0075 - val_accuracy: 0.4545
# Epoch 3/15
# 31/31 [==============================] - 6s 199ms/step - loss: 1.0722 - accuracy: 0.4204 - val_loss: 1.0224 - val_accuracy: 0.4631
# Epoch 4/15
# 31/31 [==============================] - 6s 198ms/step - loss: 1.0141 - accuracy: 0.4849 - val_loss: 1.0431 - val_accuracy: 0.4290
# Epoch 5/15
# 31/31 [==============================] - 6s 197ms/step - loss: 0.9437 - accuracy: 0.5026 - val_loss: 1.0137 - val_accuracy: 0.4688
# Epoch 6/15
# 31/31 [==============================] - 6s 198ms/step - loss: 0.9000 - accuracy: 0.5473 - val_loss: 0.8796 - val_accuracy: 0.5455
# Epoch 7/15
# 31/31 [==============================] - 6s 201ms/step - loss: 0.9577 - accuracy: 0.5286 - val_loss: 1.1265 - val_accuracy: 0.4318
# Epoch 8/15
# 31/31 [==============================] - 6s 198ms/step - loss: 1.0101 - accuracy: 0.4662 - val_loss: 0.9916 - val_accuracy: 0.5284
# Epoch 9/15
# 31/31 [==============================] - 8s 253ms/step - loss: 0.8950 - accuracy: 0.5515 - val_loss: 0.9294 - val_accuracy: 0.5341
# Epoch 10/15
# 31/31 [==============================] - 7s 210ms/step - loss: 0.8501 - accuracy: 0.5838 - val_loss: 0.9635 - val_accuracy: 0.5085
# Epoch 11/15
# 31/31 [==============================] - 6s 197ms/step - loss: 0.8295 - accuracy: 0.5806 - val_loss: 0.9590 - val_accuracy: 0.4943
# Epoch 12/15
# 31/31 [==============================] - 6s 202ms/step - loss: 0.8565 - accuracy: 0.5682 - val_loss: 0.9449 - val_accuracy: 0.5511
# Epoch 13/15
# 31/31 [==============================] - 6s 199ms/step - loss: 0.7960 - accuracy: 0.6087 - val_loss: 0.8547 - val_accuracy: 0.5938
# Epoch 14/15
# 31/31 [==============================] - 6s 199ms/step - loss: 0.7492 - accuracy: 0.6493 - val_loss: 0.9906 - val_accuracy: 0.5881
# Epoch 15/15
# 31/31 [==============================] - 6s 203ms/step - loss: 0.7348 - accuracy: 0.6483 - val_loss: 0.8382 - val_accuracy: 0.6278

# %% [markdown]
# Save the trained the model

# %%
#save model 
model.save('alert.h5')

# %%
print(x_train.class_indices)
# Out:
# {'Domestic': 0, 'Human': 1, 'Wild': 2}

# %% [markdown]
# Random image prediction

# %%
#import numpy library
import numpy as np
#import load_model method to load our saved model
from keras.models import load_model
#import image from keras.preprocessing
from keras.preprocessing import image
#loading our saved model file
model = load_model("alert.h5")
img = image.load_img(r"../Dataset/test_set/Domestic/domestic (20).jpg",
                     target_size=(64,64))

x = image.img_to_array(img)
#expanding the shape of image to 4 dimensions
x = np.expand_dims(x,axis=0)
pred = np.argmax(model.predict(x))
pred
# Out:
# 0

# %%
print(pred)
# Out:
# 0

# %% [markdown]
# Video streaming and alerting

# %%
#import opencv
import cv2
#import numpy
import numpy as np
from keras.preprocessing import image 
from keras.models  import load_model
#import Client from twilio API
from twilio.rest import Client
#import playsound package
from playsound import playsound

#Load saved model file using load_model method
model = load_model('alert.h5')
#To read webcam
video = cv2.VideoCapture(0)
#Type of classes or names of the labels that we considered
name = ['Human','Domestic', 'Wild']
#To execute the program repeatedly using while loop   
while(1):
    success, frame = video.read()
    cv2.imwrite("image.jpg",frame)
    img = image.load_img("image.jpg",target_size = (64,64))
    x  = image.img_to_array(img)
    x = np.expand_dims(x,axis = 0)
    pred = np.argmax(model.predict(x))
    p = pred
    print(pred)
    cv2.putText(frame, "predicted  class = "+str(name[p]), (100,100), 
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 1)
    
    pred = model.predict_classes(x)
    if pred[0]==2:
        #twilio account ssid
        account_sid = 'AC7031a31cfcc98cf64e0eef7d283434a8'
        #twilo account authentication toke
        auth_token = '84df78b8573a5fede90d9b8217dde66f'
        client = Client(account_sid, auth_token)

        message = client.messages \
        .create(
         body='Danger!. Wild animal is detected, stay alert',
         from_='+16468467615', #the free number of twilio
         to='+916301692688') #enter your number here
        print(message.sid)
        print('Danger!!')
        print('Animal Detected')
        print ('SMS sent!')
        #playsound(r'C:\Users\DELL\Downloads\Tornado_Siren_II-Delilah-0.mp3')
        #break
    else:
        print("No Danger")
       #break
    cv2.imshow("image",frame)
    if cv2.waitKey(1) & 0xFF == ord('a'): 
        break

video.release()
cv2.destroyAllWindows()
# Out:
# 1
# No Danger
# 1
# C:\Users\Manasa\anaconda3\lib\site-packages\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 0
# No Danger
# 0
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger
# 1
# No Danger

# %% [markdown]
# Video Streaming

# %%
import cv2
#import facevec
import numpy as np
from keras.preprocessing import image 
from keras.models  import load_model

model = load_model('alert.h5') 
video = cv2.VideoCapture(0)
name = ["Human","Wild aniaml","otimher"]
    
while(1):
    success, frame = video.read()
    cv2.imwrite("image.jpg",frame)
    img = image.load_img("image.jpg",target_size = (64,64))
    x  = image.img_to_array(img)
    x = np.expand_dims(x,axis = 0)
    pred = model.predict_classes(x)
    p = pred[0]
    print(pred)
    cv2.putText(frame, "predicted  class = "+str(name[p]), (100,100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 1)
    cv2.imshow("image",frame)
    if cv2.waitKey(1) & 0xFF == ord('a'): 
        break

video.release()
cv2.destroyAllWindows()
